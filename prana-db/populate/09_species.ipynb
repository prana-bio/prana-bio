# %% [markdown]
# Approach (worked - 90k records in 15 min)

# %%
import pandas as pd
import psycopg2
import os
import uuid
import logging
from dotenv import load_dotenv
from psycopg2 import pool
from concurrent.futures import ThreadPoolExecutor

# Configure logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# Create console handler and set level to INFO
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)

# Create formatter
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# Add formatter to console handler
ch.setFormatter(formatter)

# Add console handler to logger
logger.addHandler(ch)

# Load environment variables from .env file
load_dotenv()

# Connection parameters
dbname = os.getenv("DB_NAME")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
max_connections = 5  # Adjust the maximum number of connections as needed

# Function to insert data into the PostgreSQL table
def insert_data(chunk_df):
    try:
        # Get a connection from the connection pool
        conn = db_pool.getconn()
        cursor = conn.cursor()

        # Iterate over chunk DataFrame and insert data into the table
        for index, row in chunk_df.iterrows():
            species_id = str(row['species_id'])
            iucn_category_id = str(row['iucn_category_id'])
            iucn_taxon_id = str(row['iucn_taxon_id'])
            cursor.execute("""
                INSERT INTO species (
                    species_id,
                    iucn_category_id,
                    iucn_taxon_id,
                    common_name,
                    binominal_name,
                    name_language,
                    species_group,
                    total_habitat_range_area,
                    small_habitat_range_area,
                    created,
                    updated
                ) VALUES (
                    # %s, %s, %s, %s, %s, %s, %s, %s, %s, current_timestamp, current_timestamp
                )""", (
                    species_id,
                    iucn_category_id,
                    iucn_taxon_id,
                    row['common_name'],
                    row['binomial'],
                    row['name_language'],
                    row['group'], 
                    row['total_area'],
                    row['small_range']
                )
            )
        # Commit the transaction
        conn.commit()
        # Return connection to the pool
        db_pool.putconn(conn)
        logger.info(f"Inserted {len(chunk_df)} records into the database.")
    except Exception as e:
        logger.error(f"Error inserting data: {e}")
        if conn:
            conn.rollback()
            db_pool.putconn(conn)

# Create a connection pool
db_pool = psycopg2.pool.SimpleConnectionPool(minconn=1, maxconn=max_connections,
                                             dbname=dbname, user=user,
                                             password=password, host=host,
                                             port=port)

# Read the CSV file into a DataFrame
csv_file = '../data/countries_species.csv'
df = pd.read_csv(csv_file)

# Drop irrelevant columns
df.drop(columns=['iso_a3', 'wb_datanam', 'wb_iso', 'datanam_area', 'datanam_pct_area'], inplace=True)

# Fetch data from the iucn_categories table
query = "SELECT iucn_category_id, abbreviation FROM iucn_categories"
with psycopg2.connect(dbname=dbname, user=user, password=password, host=host, port=port) as conn:
    with conn.cursor() as cursor:
        cursor.execute(query)
        iucn_categories = cursor.fetchall()

# Create a dictionary for mapping iucn_category abbreviations to ids
iucn_category_mapping = {abbreviation: iucn_category_id for iucn_category_id, abbreviation in iucn_categories}

# Map iucn_category_id to the DataFrame using 'iucn_category' column
df['iucn_category_id'] = df['iucn_category'].map(iucn_category_mapping)

# Drop the 'iucn_category' column as it's no longer needed
df.drop(columns=['iucn_category'], inplace=True)

# Rename 'iucn_id_no' column to 'iucn_taxon_id' to match the table schema
df.rename(columns={'iucn_id_no': 'iucn_taxon_id'}, inplace=True)

df['iucn_taxon_id'] = df['iucn_taxon_id'].astype(str).str.replace('\.0', '', regex=True)

# Replace missing values in 'iucn_category_id' with the UUID corresponding to 'DD' abbreviation
dd_uuid_query = "SELECT iucn_category_id FROM iucn_categories WHERE abbreviation = 'DD'"
with psycopg2.connect(dbname=dbname, user=user, password=password, host=host, port=port) as conn:
    with conn.cursor() as cursor:
        cursor.execute(dd_uuid_query)
        dd_uuid = cursor.fetchone()[0]

df['iucn_category_id'].fillna(dd_uuid, inplace=True)

# Drop duplicates based on relevant columns
relevant_columns = ['group', 'binomial', 'common_name', 'name_language', 'total_area', 'small_range']
df.drop_duplicates(subset=relevant_columns, keep='first', inplace=True)

# Generate UUIDs for the species_id column
df['species_id'] = [uuid.uuid4() for _ in range(len(df))]

# # Save DataFrame to CSV file
# csv_output_file = '../data/countries_species_processed.csv'
# df.to_csv(csv_output_file, index=False)

# logger.info(f"Processed data saved to {csv_output_file}")

# Insert data into the PostgreSQL table in parallel using ThreadPoolExecutor
chunk_size = 50
total_records = len(df)
logger.info(f"Total records to insert: {total_records}")
with ThreadPoolExecutor() as executor:
    futures = []
    for i in range(0, total_records, chunk_size):
        chunk_df = df[i:i+chunk_size]
        futures.append(executor.submit(insert_data, chunk_df))
    for future in futures:
        future.result()

logger.info("Data insertion completed successfully.")
# Out:
# C:\Users\conno\AppData\Local\Temp\ipykernel_10296\2837328796.py:96: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# 2024-03-02 17:00:23,750 - INFO - Total records to insert: 91220
# 2024-03-02 17:00:31,058 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:32,709 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:33,058 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:33,366 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:33,984 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:34,065 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:34,742 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:34,742 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:36,198 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:37,760 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:39,718 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:40,258 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:41,038 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:41,241 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:42,478 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:43,393 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:43,928 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:44,508 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:46,588 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:47,118 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:48,268 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:49,028 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:49,878 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:50,258 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:52,138 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:52,341 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:53,431 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:53,898 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:54,558 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:55,378 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:56,258 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:57,358 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:58,470 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:59,268 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:00:59,889 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:01,085 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:01,220 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:01,458 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:03,468 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:04,120 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:04,818 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:05,718 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:06,878 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:07,079 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:07,817 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:09,338 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:10,432 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:10,465 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:10,938 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:11,551 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:11,751 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:12,958 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:15,386 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:15,838 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:16,828 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:16,988 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:17,108 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:17,125 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:17,906 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:18,625 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:20,398 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:22,668 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:22,859 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:23,368 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:23,496 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:23,878 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:23,988 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:24,236 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:25,062 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:28,899 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:28,978 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:29,349 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:29,426 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:29,439 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:29,908 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:30,214 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:31,166 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:33,858 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:33,886 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:34,921 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:35,010 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:35,117 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:35,478 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:36,272 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:37,753 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:37,771 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:38,028 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:39,398 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:39,578 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:39,724 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:39,958 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:41,818 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:42,178 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:43,011 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:43,598 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:44,378 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:44,402 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:44,525 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:44,678 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:46,448 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:46,861 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:47,288 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:48,379 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:48,868 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:48,888 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:48,932 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:49,268 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:50,538 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:51,520 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:51,749 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:52,738 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:52,968 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:53,248 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:53,258 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:53,608 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:54,568 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:56,103 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:56,502 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:57,358 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:57,469 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:57,688 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:57,709 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:58,108 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:01:58,808 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:00,528 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:00,708 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:01,678 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:02,096 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:02,248 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:02,281 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:02,616 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:03,068 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:05,048 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:05,176 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:05,944 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:06,494 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:06,668 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:06,678 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:07,068 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:07,211 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:10,018 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:10,438 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:10,693 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:11,265 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:11,731 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:11,764 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:11,938 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:12,218 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:14,378 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:14,738 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:15,201 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:15,552 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:15,774 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:15,958 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:16,350 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:16,502 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:18,598 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:18,708 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:19,494 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:19,688 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:19,750 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:20,078 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:20,739 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:20,823 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:22,724 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02:22,744 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:02
- INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:29,445 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:29,517 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:29,582 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:29,902 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:30,189 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:30,252 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:31,034 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:32,455 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:33,895 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:33,960 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:33,972 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:34,027 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:34,596 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:34,630 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:34,941 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:36,559 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:38,027 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:38,110 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:38,185 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:38,246 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:38,885 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:39,111 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:39,172 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:40,533 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:42,165 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:42,347 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:42,585 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:42,639 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:43,031 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:43,882 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:44,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:44,725 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:46,355 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:46,667 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:47,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:47,068 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:47,108 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:48,505 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:48,578 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:48,775 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:50,375 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:50,792 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:51,075 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:51,393 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:51,488 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:52,806 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:53,092 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:53,104 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:54,295 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:54,891 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:55,035 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:55,645 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:55,725 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:56,826 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:57,476 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:57,485 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:58,332 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:59,015 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:59,015 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:15:59,910 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:00,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:00,865 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:02,215 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:02,228 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:02,780 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:03,285 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:03,548 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:04,665 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:04,865 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:05,215 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:06,729 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:06,753 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:06,777 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:07,245 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:07,666 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:08,877 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:09,119 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:09,305 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:10,995 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:11,359 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:11,375 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:11,515 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:12,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:13,373 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:13,391 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:13,556 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:14,965 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:15,545 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:15,945 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:16,130 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:16,258 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:17,509 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:17,759 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:17,970 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:19,077 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:19,627 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:20,342 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:20,415 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:20,565 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:21,415 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:21,979 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:22,225 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:23,084 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:23,625 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:24,581 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:24,785 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:25,101 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:25,505 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:26,271 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:26,435 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:27,055 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:27,649 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:28,802 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:29,391 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:29,602 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:29,720 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:30,665 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:30,959 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:31,198 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:31,689 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:32,971 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:33,691 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:33,806 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:34,179 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:35,175 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:35,195 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:35,329 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:35,689 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:37,128 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:38,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:38,314 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:38,828 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:39,176 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:39,615 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:39,915 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:40,070 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:41,279 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:42,096 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:43,065 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:43,447 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:43,565 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:43,798 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:44,388 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:44,655 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:45,566 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:46,377 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:47,545 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:47,675 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:47,865 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:48,235 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:49,023 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:49,202 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:49,865 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:50,309 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:51,525 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:51,925 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:52,265 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:52,805 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:53,275 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:53,799 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:54,015 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:54,395 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:55,575 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:55,942 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:56,905 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:57,616 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:57,624 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:58,125 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:58,369 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:58,445 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:59,810 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:16:59,866 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:01,618 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:02,595 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:02,675 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:02,680 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:02,947 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:03,280 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:04,248 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:04,267 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:06,035 - INFO - Inserted 20 records into the database.
# 2024-03-02 17:17:06,705 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:07,005 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:07,195 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:07,241 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:07,555 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:07,816 - INFO - Inserted 50 records into the database.
# 2024-03-02 17:17:08,360 - INFO - Inserted 50 records into the database.

# %% [markdown]
# Save output to file for next step

# %%
import pandas as pd
import psycopg2
import os
import uuid
import logging
from dotenv import load_dotenv
from psycopg2 import pool
from concurrent.futures import ThreadPoolExecutor

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Load environment variables from .env file
load_dotenv()

# Connection parameters
dbname = os.getenv("DB_NAME")
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
max_connections = 5  # Adjust the maximum number of connections as needed

# Function to insert data into the PostgreSQL table
def insert_data(chunk_df):
    try:
        # Get a connection from the connection pool
        conn = db_pool.getconn()
        cursor = conn.cursor()

        # Iterate over chunk DataFrame and insert data into the table
        for index, row in chunk_df.iterrows():
            species_id = str(row['species_id'])
            iucn_category_id = str(row['iucn_category_id'])
            iucn_taxon_id = str(row['iucn_taxon_id'])
            cursor.execute("""
                INSERT INTO species (
                    species_id,
                    iucn_category_id,
                    iucn_taxon_id,
                    common_name,
                    binominal_name,
                    name_language,
                    species_group,
                    total_habitat_range_area,
                    small_habitat_range_area,
                    created,
                    updated
                ) VALUES (
                    # %s, %s, %s, %s, %s, %s, %s, %s, %s, current_timestamp, current_timestamp
                )""", (
                    species_id,
                    iucn_category_id,
                    iucn_taxon_id,
                    row['common_name'],
                    row['binomial'],
                    row['name_language'],
                    row['group'], 
                    row['total_area'],
                    row['small_range']
                )
            )
        # Commit the transaction
        conn.commit()
        # Return connection to the pool
        db_pool.putconn(conn)
        logger.info(f"Inserted {len(chunk_df)} records into the database.")
    except Exception as e:
        logger.error(f"Error inserting data: {e}")
        if conn:
            conn.rollback()
            db_pool.putconn(conn)

# Create a connection pool
db_pool = psycopg2.pool.SimpleConnectionPool(minconn=1, maxconn=max_connections,
                                             dbname=dbname, user=user,
                                             password=password, host=host,
                                             port=port)

# Read the CSV file into a DataFrame
csv_file = '../data/countries_species.csv'
df = pd.read_csv(csv_file)

# Drop irrelevant columns
df.drop(columns=['iso_a3', 'wb_datanam', 'wb_iso', 'datanam_area', 'datanam_pct_area'], inplace=True)

# Fetch data from the iucn_categories table
query = "SELECT iucn_category_id, abbreviation FROM iucn_categories"
with psycopg2.connect(dbname=dbname, user=user, password=password, host=host, port=port) as conn:
    with conn.cursor() as cursor:
        cursor.execute(query)
        iucn_categories = cursor.fetchall()

# Create a dictionary for mapping iucn_category abbreviations to ids
iucn_category_mapping = {abbreviation: iucn_category_id for iucn_category_id, abbreviation in iucn_categories}

# Map iucn_category_id to the DataFrame using 'iucn_category' column
df['iucn_category_id'] = df['iucn_category'].map(iucn_category_mapping)

# Drop the 'iucn_category' column as it's no longer needed
df.drop(columns=['iucn_category'], inplace=True)

# Rename 'iucn_id_no' column to 'iucn_taxon_id' to match the table schema
df.rename(columns={'iucn_id_no': 'iucn_taxon_id'}, inplace=True)

df['iucn_taxon_id'] = df['iucn_taxon_id'].astype(str).str.replace('\.0', '', regex=True)

# Replace missing values in 'iucn_category_id' with the UUID corresponding to 'DD' abbreviation
dd_uuid_query = "SELECT iucn_category_id FROM iucn_categories WHERE abbreviation = 'DD'"
with psycopg2.connect(dbname=dbname, user=user, password=password, host=host, port=port) as conn:
    with conn.cursor() as cursor:
        cursor.execute(dd_uuid_query)
        dd_uuid = cursor.fetchone()[0]

df['iucn_category_id'].fillna(dd_uuid, inplace=True)

# Drop duplicates based on relevant columns
relevant_columns = ['group', 'binomial', 'common_name', 'name_language', 'total_area', 'small_range']
df.drop_duplicates(subset=relevant_columns, keep='first', inplace=True)

# Generate UUIDs for the species_id column
df['species_id'] = [uuid.uuid4() for _ in range(len(df))]

# Save DataFrame to CSV file
csv_output_file = '../data/countries_species_processed.csv'
df.to_csv(csv_output_file, index=False)

logger.info(f"Processed data saved to {csv_output_file}")

# Insert data into the PostgreSQL table in parallel using ThreadPoolExecutor
chunk_size = 50
total_records = len(df)
logger.info(f"Total records to insert: {total_records}")
with ThreadPoolExecutor() as executor:
    futures = []
    for i in range(0, total_records, chunk_size):
        chunk_df = df[i:i+chunk_size]
        futures.append(executor.submit(insert_data, chunk_df))
    for future in futures:
        future.result()

logger.info("Data insertion completed successfully.")
